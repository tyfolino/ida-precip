# %% [markdown]
# ## Setup

# %%
# Import statements

import xarray as xr

# %%
test = xr.open_mfdataset("/mnt/drive2/wof-runs/adaptor*.nc")

# %%
test
# Out:
# <xarray.Dataset> Size: 10GB
# Dimensions:    (longitude: 1440, latitude: 721, time: 48)
# Coordinates:
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 384B 2021-09-01 ... 2021-09-02T23:00:00
# Data variables: (12/25)
#     u10        (time, latitude, longitude) float64 399MB dask.array<chunksize=(48, 721, 1440), meta=np.ndarray>
#     v10        (time, latitude, longitude) float64 399MB dask.array<chunksize=(48, 721, 1440), meta=np.ndarray>
#     d2m        (time, latitude, longitude) float64 399MB dask.array<chunksize=(48, 721, 1440), meta=np.ndarray>
#     t2m        (time, latitude, longitude) float64 399MB dask.array<chunksize=(48, 721, 1440), meta=np.ndarray>
#     cape       (time, latitude, longitude) float64 399MB dask.array<chunksize=(48, 721, 1440), meta=np.ndarray>
# ...
